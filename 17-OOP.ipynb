# %%
atilName = "Atil"

# %%
atilAge = 98

# %%
atilGender = "Male"

# %%
atlasName = "Atlas"

# %%
atlasAge = 10

# %%
atlasGender = "Male"

# %%
class Person():
    #property
    #name = ""
   # age = 0
   # gender = ""
    job = "developer"

    #method, initiliazer method
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    #method
    
    def printName(self):
        print(self.name)

# %%
atil = Person("Atil",35,"Male")

# %%
type(atil)
# Out:
# __main__.Person

# %%
atil.name
# Out:
# 'Atil'

# %%
atil.age
# Out:
# 35

# %%
atil.gender
# Out:
# 'Male'

# %%
atil.printName
# Out:
# <bound method Person.printName of <__main__.Person object at 0x00000152D3A6FA10>>

# %%
atil.job
# Out:
# 'developer'

# %%
atil.job = "İnstructor"

# %%
atil.job
# Out:
# 'developer'

# %%
class Dog():

    year = 7
    def __init__(self,age=5):
        self.age = age
        self.dogHumanAge = age *self.year
        print("dog instance")
    def humanAge(self):
        return self.age * self.year  #Dog.year -> self.year

# %%
myDog = Dog(3)
# Out:
# dog instance

# %%
myDog.age
# Out:
# 3

# %%
myDog.humanAge()
# Out:
# 21

# %%
myDog.dogHumanAge
# Out:
# 21

# %%
barley = Dog()
# Out:
# dog instance

# %%
barley.dogHumanAge
# Out:
# 35
