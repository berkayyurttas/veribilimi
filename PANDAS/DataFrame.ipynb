# %%
import numpy as np

# %%
import pandas as pd

# %%
data = np.random.rand(4,3)

# %%
data
# Out:
# array([[1.38307394e-01, 2.14281899e-01, 5.91552327e-03],
#        [3.50102608e-04, 4.70318778e-01, 2.83956998e-01],
#        [7.48364200e-01, 7.82353300e-01, 6.65662918e-01],
#        [5.11404596e-01, 5.31680381e-01, 6.99782190e-01]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  0.138307  0.214282  0.005916
# 1  0.000350  0.470319  0.283957
# 2  0.748364  0.782353  0.665663
# 3  0.511405  0.531680  0.699782

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(data, index =["Atil","Zeynep","Atlas","Mehmet"],columns= ["Salary","Age","Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663
# Mehmet  0.511405  0.531680   0.699782

# %%
new_df["Age"]
# Out:
# Atil      0.214282
# Zeynep    0.470319
# Atlas     0.782353
# Mehmet    0.531680
# Name: Age, dtype: float64

# %%
new_df["Age"]
# Out:
# Atil      0.214282
# Zeynep    0.470319
# Atlas     0.782353
# Mehmet    0.531680
# Name: Age, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#              Age    Salary
# Atil    0.214282  0.138307
# Zeynep  0.470319  0.000350
# Atlas   0.782353  0.748364
# Mehmet  0.531680  0.511405

# %%
new_df.loc["Atil"]
# Out:
# Salary       0.138307
# Age          0.214282
# Seniority    0.005916
# Name: Atil, dtype: float64

# %%
new_df.iloc[1]
# Out:
# Salary       0.000350
# Age          0.470319
# Seniority    0.283957
# Name: Zeynep, dtype: float64

# %%
new_df.iloc[0]
# Out:
# Salary       0.138307
# Age          0.214282
# Seniority    0.005916
# Name: Atil, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663
# Mehmet  0.511405  0.531680   0.699782

# %%
new_df.iloc[:,1] #: bütün rowları seç
# Out:
# Atil      0.214282
# Zeynep    0.470319
# Atlas     0.782353
# Mehmet    0.531680
# Name: Age, dtype: float64

# %% [markdown]
# DATA MANİPÜLASYONU

# %%
new_df["Age"]
# Out:
# Atil      0.214282
# Zeynep    0.470319
# Atlas     0.782353
# Mehmet    0.531680
# Name: Age, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil    0.138307  0.214282   0.005916     10
# Zeynep  0.000350  0.470319   0.283957     10
# Atlas   0.748364  0.782353   0.665663     10
# Mehmet  0.511405  0.531680   0.699782     10

# %%
new_df.drop("Extra", axis=1)
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663
# Mehmet  0.511405  0.531680   0.699782

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil    0.138307  0.214282   0.005916     10
# Zeynep  0.000350  0.470319   0.283957     10
# Atlas   0.748364  0.782353   0.665663     10
# Mehmet  0.511405  0.531680   0.699782     10

# %%
new_df.drop(columns=["Extra"], inplace=True)

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663
# Mehmet  0.511405  0.531680   0.699782

# %%
new_df.drop("Mehmet")
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663

# %%
new_df.drop("Mehmet", axis=0)
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil    0.138307  0.214282   0.005916
# Zeynep  0.000350  0.470319   0.283957
# Atlas   0.748364  0.782353   0.665663
# Mehmet  0.511405  0.531680   0.699782

# %%
new_df.loc["Atlas"]
# Out:
# Salary       0.748364
# Age          0.782353
# Seniority    0.665663
# Name: Atlas, dtype: float64

# %%
new_df.loc["Atlas"]["Salary"]
# Out:
# np.float64(0.7483642002523234)

# %%
new_df.loc["Atlas","Salary"] = 100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.138307  0.214282   0.005916
# Zeynep    0.000350  0.470319   0.283957
# Atlas   100.000000  0.782353   0.665663
# Mehmet    0.511405  0.531680   0.699782

# %%
new_df > 0
# Out:
#         Salary   Age  Seniority
# Atil      True  True       True
# Zeynep    True  True       True
# Atlas     True  True       True
# Mehmet    True  True       True

# %%
boolean_frame = new_df <0

# %%
new_df[boolean_frame]
# Out:
#         Salary  Age  Seniority
# Atil       NaN  NaN        NaN
# Zeynep     NaN  NaN        NaN
# Atlas      NaN  NaN        NaN
# Mehmet     NaN  NaN        NaN

# %%
new_df[new_df >0]
# Out:
#             Salary       Age  Seniority
# Atil      0.138307  0.214282   0.005916
# Zeynep    0.000350  0.470319   0.283957
# Atlas   100.000000  0.782353   0.665663
# Mehmet    0.511405  0.531680   0.699782

# %%
new_df.reset_index()
# Out:
#     index      Salary       Age  Seniority
# 0    Atil    0.138307  0.214282   0.005916
# 1  Zeynep    0.000350  0.470319   0.283957
# 2   Atlas  100.000000  0.782353   0.665663
# 3  Mehmet    0.511405  0.531680   0.699782

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0    Atil    0.138307  0.214282   0.005916
# 1  Zeynep    0.000350  0.470319   0.283957
# 2   Atlas  100.000000  0.782353   0.665663
# 3  Mehmet    0.511405  0.531680   0.699782

# %%
reset_frame.loc[0]
# Out:
# index            Atil
# Salary       0.138307
# Age          0.214282
# Seniority    0.005916
# Name: 0, dtype: object

# %%
new_indices = ["Ati","Zey","Atl","Meh"]

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.138307  0.214282   0.005916
# Zeynep    0.000350  0.470319   0.283957
# Atlas   100.000000  0.782353   0.665663
# Mehmet    0.511405  0.531680   0.699782

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil      0.138307  0.214282   0.005916
# Zeynep    0.000350  0.470319   0.283957
# Atlas   100.000000  0.782353   0.665663
# Mehmet    0.511405  0.531680   0.699782

# %%
new_df = new_df.reset_index()

# %%
print(new_df.index.name)
# Out:
# None

# %%
print(list(new_df.columns))
# Out:
# ['index', 'Salary', 'Age', 'Seniority']

# %%
# Sütun isimlerindeki boşlukları siler ve hepsini standart hale getirir
new_df.columns = new_df.columns.str.strip()

# %%
# Şimdi tekrar deneyin
new_df = new_df.set_index("NewIndex")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3004\82657876.py in ?()
#       1 # Şimdi tekrar deneyin
# ----> 2 new_df = new_df.set_index("NewIndex")
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['NewIndex'] are in the columns"

# %%
##multi index

# %%
first_index = ["Simpson","Simpson","Simpson","South Park", "South Park", "South Park"]

# %%
inner_index = ["Honer", "Bart", "Marge", "Cartman", "Kenny", "Kyle"]

# %%
zipped_index = list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Honer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Honer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values, index=zipped_index, columns = ["Age", "Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Honer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Honer  1.0     1.0
# Bart   1.0     1.0
# Marge  1.0     1.0

# %%
big_df.loc["Simpson"].loc["Honer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Honer, dtype: float64
