# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Ben Berkay Nasılsın?")
# Out:
# Ben Berkay Nasılsın?

# %%
name="atıl"

# %%
type(name)
# Out:
# str

# %%
'atıil samancioğlu'
# Out:
# 'atıil samancioğlu'

# %%
type('atil restaurant')
# Out:
# str

# %%
"atil's restaurant"
# Out:
# "atil's restaurant"

# %%
type(5+4)
# Out:
# int

# %%
type("5+4")
# Out:
# str

# %%
name ="Berkay Yurttaş"

# %%
name.capitalize()
# Out:
# 'Berkay yurttaş'

# %%
name.upper()
# Out:
# 'BERKAY YURTTAŞ'

# %%
name.lower()
# Out:
# 'berkay yurttaş'

# %%
x=10

# %%
x.real
# Out:
# 10

# %%
x.bit_length
# Out:
# <function int.bit_length()>

# %%
x.as_integer_ratio()
# Out:
# (10, 1)

# %%
x.denominator
# Out:
# 1

# %%
x.is_integer()
# Out:
# True

# %%
name = "Berkay Yurttaş"

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name.count("a")
# Out:
# 2

# %%
name.count("c")
# Out:
# 0

# %%
name.upper()
# Out:
# 'BERKAY YURTTAŞ'

# %%
name.count("y")
# Out:
# 1

# %%
name.upper()
# Out:
# 'BERKAY YURTTAŞ'

# %%
name
# Out:
# 'Berkay Yurttaş'

# %%
x=10
y=5

# %%
x+y
# Out:
# 15

# %%
z=x+y

# %%
z
# Out:
# 15

# %%
name
# Out:
# 'Berkay Yurttaş'

# %%
name.upper()
# Out:
# 'BERKAY YURTTAŞ'

# %%
nameUpper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 nameUpper
#
# NameError: name 'nameUpper' is not defined

# %%
name
# Out:
# 'Berkay Yurttaş'

# %%
print(name.upper())
# Out:
# BERKAY YURTTAŞ

# %%
help(name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
len(name) #lenght;
# Out:
# 14

# %%
print("berkay yurttaş")
# Out:
# berkay yurttaş

# %%
print("berkay \nyurttaş")
# Out:
# berkay
# yurttaş

# %%
#\n ->new line

# %%
#escape characters

# %%
#\t-! tab

# %%
print("berkay \tyurttaş")
# Out:
# berkay 	yurttaş

# %%
len("berkay  yurttas")
# Out:
# 15
