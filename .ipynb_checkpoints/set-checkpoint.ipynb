# %%
#unique elemanlar tekil yani her elemandan bir tane olabilir ve unordered sırasız yani

# %%
myList = [10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,10,20,40,10,20,40}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(60)

# %%
mySet
# Out:
# {10, 20, 30, 40, 60}

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet
# Out:
# {10, 20, 30, 40, 60}

# %%
mySet2
# Out:
# {30, 40, 50, 60, 70}

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2)
# Out:
# {30, 40, 60}

# %%
countryList = ["de","fr","tr","fr","tr","de","nl","de","tr"]

# %%
len(countryList)
# Out:
# 9

# %%
len(set(countryList))
# Out:
# 4

# %%
emptyList = []

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10,
#  20,
#  10,
#  20,
#  30,
#  10,
#  20,
#  30,
#  10,
#  20,
#  30,
#  10,
#  20,
#  30,
#  10,
#  20,
#  30,
#  10,
#  20,
#  30,
#  10,
#  20,
#  30]

# %%
emptySet = {}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptyList = list()

# %%
emptyList.append(20)

# %%
emptyList
# Out:
# [20]

# %%
emptyDictionary = dict()

# %%
emptyDictionary["a"]= 10
emptyDictionary["b"] = 20

# %%
emptyDictionary
# Out:
# {'a': 10, 'b': 20}
