# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[0]
# Out:
# 'h'

# %%
myString[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myString[12]
#
# IndexError: string index out of range

# %%
myString[11]
# Out:
# 'n'

# %%
myString[10]
# Out:
# 'o'

# %%
myString= "atil samancioğlu"

# %%
myString[4]
# Out:
# ' '

# %%
myString[5]
# Out:
# 's'

# %%
len(myString)
# Out:
# 16

# %%
len(myString)-1
# Out:
# 15

# %%
myName ="james heltfield"

# %%
myName[len(myName)-1]
# Out:
# 'd'

# %%
myName[-1]
# Out:
# 'd'

# %%
myName[-2]
# Out:
# 'l'

# %%
barcode = "ABCDE123123982"

# %%
barcode[1]
# Out:
# 'B'

# %%
barcode[2]
# Out:
# 'C'

# %%
10 +20
# Out:
# 30

# %%
"A" +"B"
# Out:
# 'AB'

# %%
name ="atil"

# %%
surname ="samancioğlu"

# %%
fullname = name +""+surname

# %%
fullname
# Out:
# 'atilsamancioğlu'

# %%
fullname * 5
# Out:
# 'atilsamancioğluatilsamancioğluatilsamancioğluatilsamancioğluatilsamancioğlu'

# %%
100 * "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
fullname / 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 fullname / 5
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
barcode[0] + barcode [1] + barcode[2]
# Out:
# 'ABC'

# %%
#slicing, starting index, stopping index, stepping size

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
#barcode[starting index: stoppling index: stepping size]

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
barcode[:3:] #3. indexte dur
# Out:
# 'ABC'

# %%
barcode[4::]
# Out:
# 'E123123982'

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
barcode[3:5]
# Out:
# 'DE'

# %%
barcode[1:9:2]
# Out:
# 'BD13'

# %%
barcode[::-1]
# Out:
# '289321321EDCBA'

# %%
barcode
# Out:
# 'ABCDE123123982'

# %%
name = "atil samancioğlu"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.

# %%
name.index("s")
# Out:
# 5

# %%
name.split()
# Out:
# ['atil', 'samancioğlu']
