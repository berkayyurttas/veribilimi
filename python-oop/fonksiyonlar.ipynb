# %%
#method vs function

# %%
my_name = "atil"

# %%
my_name.upper()
# Out:
# 'ATIL'

# %%
my_name
# Out:
# 'atil'

# %%
my_name_upper = my_name.upper()

# %%
my_name_upper
# Out:
# 'ATIL'

# %%
my_name
# Out:
# 'atil'

# %%
help(my_name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
#functions

# %%
def hello_python():
    print("hello")
    print("python")

# %%
hello_python
# Out:
# <function __main__.hello_python()>

# %%
hello_python()
# Out:
# hello
# python

# %%
hello_python()
# Out:
# hello
# python

# %%
#input

# %%
def hello_name(name):
    print("hello")
    print(name)

# %%
hello_name("python")
# Out:
# hello
# python

# %%
hello_name("atil")
# Out:
# hello
# atil

# %%
def sum_example(num1, num2):
    print(num1+num2)

# %%
sum_example(20,12)
# Out:
# 32

# %%
def sum_example(num1, num2):
    num3 = num1 + num2
    print(num3)

# %%
sum_example(20,12)
# Out:
# 32

# %%
hello_name("required")
# Out:
# hello
# required

# %%
def hello_surname(surname="samancioğlu"):
    print("hello")
    print(surname)

# %%
hello_surname("sam")
# Out:
# hello
# sam

# %%
hello_surname()
# Out:
# hello
# samancioğlu

# %%
#return

# %%
def summation(num1,num2,num3):
    print(num1+num2+num3)

# %%
summation(10,2,8)
# Out:
# 20

# %%
x = summation(10,2,8)
# Out:
# 20

# %%
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %%
def return_summation(num1,num2,num3):
    result = num1+num2+num3
    print(result)
    return num1+num2+num3

# %%
x = return_summation(10,2,8)
# Out:
# 20

# %%
x
# Out:
# 20

# %%
def control_string(s):
    if s[0] == "a":
        print("a")

# %%
control_string("atlas")
# Out:
# a

# %%
control_string("atil")
# Out:
# a

# %%
control_string("james")

# %%
# args, kwargs (arguments, key word arguments)

# %%
def args_sum(*args):
    return sum(args)

# %%
args_sum(10,20,30,40,50,60)
# Out:
# 210

# %%
def args_example(*args):
    print(args)

# %%
args_example(123,1203123,343,123,34)
# Out:
# (123, 1203123, 343, 123, 34)

# %%
def kwargs_example(**kwargs):
    print(kwargs)

# %%
kwargs_example(apple=100, banana=150, melon=2200)
# Out:
# {'apple': 100, 'banana': 150, 'melon': 2200}

# %%
def kwargs_example_2(**kwargs):
    if "apple" in kwargs:
        print("appleee")
    else:
        print(":(")

# %%
kwargs_example_2(apple=10, banana=15)
# Out:
# appleee

# %%
kwargs_example_2(banana=15)
# Out:
# :(
