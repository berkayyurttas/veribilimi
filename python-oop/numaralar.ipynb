# %%
#data type

# %%
age = 50

# %%
age *3
# Out:
# 150

# %%
typ
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 typ
#
# NameError: name 'typ' is not defined

# %%
type
# Out:
# type

# %%
type(10)
# Out:
# int

# %%
type(10 *3)
# Out:
# int

# %%
type(age * 5)
# Out:
# int

# %%
type(-1000)
# Out:
# int

# %%
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 type(x)
#
# NameError: name 'x' is not defined

# %%
x=100

# %%
type(x)
# Out:
# int

# %%
#float _> floating point

# %%
pi = 3,14

# %%
pi*2
# Out:
# (3, 14, 3, 14)

# %%
pi =3.14

# %%
pi*2
# Out:
# 6.28

# %%
x
# Out:
# 100

# %%
type(3.14)
# Out:
# float

# %%
x +pi
# Out:
# 103.14

# %%
x/pi
# Out:
# 31.84713375796178

# %%
x = 10

# %%
x = 20

# %%
x + 10
# Out:
# 30

# %%
myFloat = 1.3444442423

# %%
type(myFloat)
# Out:
# float

# %%
my_float
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 my_float
#
# NameError: name 'my_float' is not defined

# %%
myFloat
# Out:
# 1.3444442423

# %%
#camelCase
#snake_Case

# %%
40/4
# Out:
# 10.0

# %%
type(40 /4 )
# Out:
# float

# %%
40 / 9
# Out:
# 4.444444444444445

# %%
40 /13
# Out:
# 3.076923076923077

# %%
4 /2
# Out:
# 2.0

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
4 /3  #javada 1 çıkar inti inte böldüğümüzde
# Out:
# 1.3333333333333333

# %%
4.0 / 3.0
# Out:
# 1.3333333333333333

# %%
typre(4
# Out:
#   Cell In[38], line 1
#     typre(4
#            ^
# _IncompleteInputError: incomplete input

# %%
type(4)
# Out:
# int

# %%
typr(4.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 typr(4.0)
#
# NameError: name 'typr' is not defined

# %%
type(4.0)
# Out:
# float

# %%
4.1-2
# Out:
# 2.0999999999999996

# %%
type(4.1-2)
# Out:
# float

# %%
4.25-3
# Out:
# 1.25

# %%
4.4-4.9
# Out:
# -0.5

# %%
4.2 *3
# Out:
# 12.600000000000001

# %%
4.2 *3-10
# Out:
# 2.6000000000000014

# %%
2 -10*2
# Out:
# -18

# %%
2 **5 #2 üslü5
# Out:
# 32

# %%
10 %3 #kalanı bulma
# Out:
# 1
