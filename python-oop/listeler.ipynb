# %%
myString="hello world"

# %%
myString.split()
# Out:
# ['hello', 'world']

# %%
type(myString.split())
# Out:
# list

# %%
#list

# %%
myString
# Out:
# 'hello world'

# %%
myString[0]
# Out:
# 'h'

# %%
#myString[0] ="a"

# %%
#immutable - immutability

# %%
myString ="atil"

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x=10
y=20
z=30

# %%
myList =[x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList[0]
# Out:
# 10

# %%
type(myList[0])
# Out:
# int

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100

# %%
#mutable, mutability

# %%
myList
# Out:
# [100, 20, 30]

# %%
len(myList)
# Out:
# 3

# %%
myList[len(myList)-1]
# Out:
# 30

# %%
myList[len(myList)-2]
# Out:
# 20

# %%
myList
# Out:
# [100, 20, 30]

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 80, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 20, 30, 80, 80, 1]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.count(80)
# Out:
# 2

# %%
myList.index(20)
# Out:
# 1

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList
# Out:
# [100, 20, 30, 80, 80, 1]

# %%
myList.insert(2,35)

# %%
myList
# Out:
# [100, 20, 35, 30, 80, 80, 1]

# %%
myList.pop()
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 35, 30, 80, 80]

# %%
myList.remove(20)

# %%
myList
# Out:
# [100, 35, 30, 80, 80]

# %%
myList.sort()

# %%
myList
# Out:
# [30, 35, 80, 80, 100]

# %%
x = input("enter x")
# Out:
# enter x 10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
x= int(input("Klavyeden bir sayı giriniz:"))
# Out:
# Klavyeden bir sayı giriniz: 15

# %%
x
# Out:
# 15

# %%
type(x)
# Out:
# int

# %%
type(x)
# Out:
# int

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
inputList
# Out:
# []

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# [15, 20, 30]

# %%
inputList
# Out:
# [15, 20, 30]

# %%
inputList[1]
# Out:
# 20

# %%
inputList[0]
# Out:
# 15

# %%
inputList[2]
# Out:
# 30

# %%
inputList[1] *2
# Out:
# 40

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString= "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString ="python"

# %%
#int(myString)

# %%
#float(myString)

# %%
inputList
# Out:
# [15, 20, 30]

# %%
int(inputList[1]) *2
# Out:
# 40

# %%
inputList
# Out:
# [15, 20, 30]

# %%
str(inputList)
# Out:
# '[15, 20, 30]'

# %%
nameList = ["atil", "atlas", "a", "b"]

# %%
type(nameList)
# Out:
# list

# %%
floatList =  [3.14,2.5,10.2,100.123]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["atil",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [30,40,50]

# %%
list1 + list2
# Out:
# [10, 20, 30, 30, 40, 50]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#list1 /5

# %%
mixedList
# Out:
# ['atil', 100, 3.14]

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[2])
# Out:
# float

# %%
#nestedList

# %%
myNestedList = [10,20,3.14,"atil",[1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'atil'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
smallList =myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'atil', [1, 2, 3]]

# %%
smallList =myNestedList[-1]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
myNestedList[4][1]
# Out:
# 2

# %%
myNestedList[1]
# Out:
# 20
