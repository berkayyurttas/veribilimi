# %%
x = 5
y = 3
z = 6

# %%
x > y and z>x
# Out:
# True

# %%
x < y or z > y
# Out:
# True

# %%
my_dictionary = {"k1":10, "k2k":"a", "k32":30,"k4":"c"}

# %%
if "c" in my_dictionary.values():
    print("evet")
# Out:
# evet

# %%
r_list = [1,2,3,4,5,6]

# %%
pi = 3.14

# %%
cevre_list = []
for r in r_list:
    cevre_list.append(2 * pi *r)

# %%
cevre_list
# Out:
# [6.28, 12.56, 18.84, 25.12, 31.400000000000002, 37.68]

# %%
berkay_list = ["ahmet","mehmet","şefika","azra"]

# %%
from random import randint

# %%
berkay_list[randint(0,len(berkay_list))]
# Out:
# 'azra'
