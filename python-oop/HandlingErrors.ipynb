# %%
age = input("enter age: ")

# %%
age

# %%
int(age) *2

# %%
#try - except

# %%
while True:
  try:
      myAge = int(input("enter age:"))
      print(myAge * 2)
      break
  except:
    print("enter your age!!!")
  else:
      print("else executed")
  finally:
      print("finally")

# %%
berkay
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 berkay
#
# NameError: name 'berkay' is not defined
