# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
myBoolean = False

# %%
type(myBoolean)
# Out:
# bool

# %%
5 > 3
# Out:
# True

# %%
3>5
# Out:
# False

# %%
4==4
# Out:
# True

# %%
yas = int(input("Kullanıcan bir sayı giriniz:"))
# Out:
# Kullanıcan bir sayı giriniz: 15

# %%
yas
# Out:
# 15

# %%
int(yas) >18
# Out:
# False

# %%
int(yas)<18
# Out:
# True
