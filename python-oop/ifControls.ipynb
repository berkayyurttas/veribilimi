# %%
x = 5

# %%
y = 2

# %%
x >y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
y>x
# Out:
# False

# %%
y<x
# Out:
# True

# %%
y = 5

# %%
x>= y
# Out:
# True

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
x>= 5.0
# Out:
# True

# %%
x>=5.001
# Out:
# False

# %%
x=10

# %%
y=8

# %%
x
# Out:
# 10

# %%
y
# Out:
# 8

# %%
x = y

# %%
x
# Out:
# 8

# %%
y
# Out:
# 8

# %%
x = 10

# %%
y
# Out:
# 8

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %% [markdown]
# 2 > 1

# %%
2 > 1 and 3>2
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
1<2 or 3<2
# Out:
# True

# %%
not 1 ==1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
10 in {10,20,30} #set
# Out:
# True

# %%
my_dictionary = {"a":10, "b":20, "c":30}

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True

# %%
10 in (10,20,30) #tuple
# Out:
# True

# %%
my_superhero ="Batman"

# %%
my_superhero== "Batman"
# Out:
# True

# %%
my_superhero =="Superman"
# Out:
# False

# %%
if my_superhero == "Batman":
    #indentation
    print("batmannn")
    print("atil samancioğlu")
# Out:
# batmannn
# atil samancioğlu

# %%
if 3<2:
    print("hello")

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero:  Superman

# %%
if my_superhero == "Superman":
    print("Superman")
elif my_superhero == "Batman":
    print("batman")
elif my_superhero == "Aquaman":
    print("aquaman")
elif my_superhero ==" Ironman":
    print("ıronman")
else:
    print(":(")
# Out:
# Superman

# %%
my_age = 30

# %%
if my_age <= 18:
    print("age =18")
elif my_age >18 and my_age<=30: 
    print("18 - age -30")
# Out:
# 18 - age -30

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero:  Batman

# %%
my_superhero_list = ["Spider Man", "Batman","Iron Man", "Thor", "Black Widow"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")
# Out:
# :)
