# %%
x = 20

def multiply(num):
    x = 5
    return num * x

# %%
multiply(10)
# Out:
# 50

# %%
print(x)
# Out:
# 20

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = 20

# %%
a
# Out:
# 20

# %%
x = 20

def multiply(num):
    x = 5
    return num * x
x = 10

# %%
x
# Out:
# 10

# %%
multiply(3)
# Out:
# 15

# %%
x = 20

def multiply(num):
    
    return num * x

# %%
multiply(10)
# Out:
# 200

# %%
#LEGB ->L->LOCAL,E->ENCLOSİNG,G->GLOBAL,B->BUİLT-IN

# %%
#Global
myString ="Atil"

def myFunction():
    #Enclosing
    myString = "Atil 2"
    print(myString)

    def myFunction2():
        #Local
        myString = "Atıl 3"
        print(myString)
    myFunction2();

# %%
myString
# Out:
# 'Atil'

# %%
myFunction()
# Out:
# Atil 2
# Atıl 3

# %%
myString
# Out:
# 'Atil'

# %%
def test1():
    myVariable = 10
    print(myVariable * 2)

def test2():
    print(myVariable * 3)

# %%
test1()
# Out:
# 20

# %%
#test2()

# %%
y = 10
def newFunction(y):
    print(y)
    y = 5
    print(y)
    return y

# %%
newFunction(10)
# Out:
# 10
# 5
# 5

# %%
y
# Out:
# 10

# %%
y = 10

def changerY():
    global y
    y = 5
    print(y)

# %%
changeY()
# Out:
# 5

# %%
y
# Out:
# 10
